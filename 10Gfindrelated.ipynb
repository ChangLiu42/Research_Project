# %% [markdown]
# # Python Tweepy Crawler

# %%
import re
import nltk
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma

#print [lemmatize(token) for token in alltext[:100]]
from nltk.corpus import stopwords
import string
 
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via']

def final_dp (tweetin):
    terms_stop = [term for term in preprocess(tweetin.lower()) if term not in stop]
    terms_no = []
    for a in terms_stop:
        if 'http' not in a:
            if 'https' not in a:
                if '@' not in a:
                    terms_no.append(a)
    return terms_no
print final_dp(tweet)
# Out:
# ['example', ':d', '#nlp']

# %%
from sklearn.feature_extraction import DictVectorizer

def get_BOW(text):
    BOW = {}
    for word in text:
        BOW[word] = BOW.get(word,0) + 1
    return BOW

# %%
# -*- coding: utf-8 -*-  
import json
import codecs
ffkword = ['McDonald', 'maccas' ,'KFC','Subway','Domino','Pizza Hut','Nando','fastfood','fast food'] 
# ffkword = [' fat ','overweight','obese','obesity'] 

thirdfile = open('E:/middleTwitter.json','r')
containffkwordfile = codecs.open('C:/Users/LC/Desktop/Fast food research/10Ganalysis/fftwitter.json','w',encoding='utf-8')
alltext = []
i = 0
allt = 0
for line in thirdfile:
    text = []
#     print line
#     print json.loads(line, encoding='utf8')
#     break
    try:
        new = json.loads(line, encoding='utf8')
        for word in ffkword:
            if word.lower() in new['text'].lower():
                aaaa = json.dumps(new, ensure_ascii=False)
                containffkwordfile.write(aaaa+'\n')
                allt = allt + 1
                break
        i = i + 1
        if i % 10000 == 30:
            print 'processing'
    except BaseException as e:
        print('Error on_data:'+str(e))
print allt
print 'complete'
thirdfile.close()
containffkwordfile.close()
# Out:
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# processing
# ...

# %%
# -*- coding: utf-8 -*-  
import json
from nltk import bigrams 

fatword = [' fat ','overweight','obese','obesity','lose weight','low fat','slim','reduce'
            ,'keep fit','fatty','adipose','fatty tissue','chubby','plump','podgy','tubby'
            ,'blubber','sebaceous','corpulent','pudgy','greasy','avoirdupois','portly','rotund'
            ,'zaftig','fatten','blubbery','fleshy','oily','potbellied','dumpy','juicy','paunchy'
            ,'porcine','buxom','buttery','thick','jowly','thickset','rich','embonpoint','oleaginous'
            ,'stocky','gross','profitable','weighty','fatten up','heavyset','stout','fill out'
            ,'heavy','fertile','compact','productive','rounded','fruitful','abdominous','double-chinned'
            ,'endomorphic','fatten out','fattish','flesh out','loose-jowled','plump out','pyknic'
            ,'suety','superfatted','zoftig'] 
thirdfile = open('C:/Users/LC/Desktop/Fast food research/10Ganalysis/fftwitter.json','r')
alltext = []
bigramtext = []
i = 0
for line in thirdfile:
    text = []
    try:
        new = json.loads(line, encoding='utf8')
        for a in fatword:
            if a in new['text']:
                i = i + 1
                break
        alltext.extend(final_dp(new['text']))
        terms_bigram = bigrams(final_dp(new['text']))
        bigramtext.extend(terms_bigram)
    except BaseException as e:
        print('Error on_data:'+str(e))
print 'complete'
thirdfile.close()
print i
# Out:
# complete
# 84

# %%
print len(alltext)
print len(bigramtext)
# Out:
# 27426
# 24852

# %%
get_BOW(alltext)
# Out:
# {u'raining': 1,
#  u"#usyd's": 3,
#  u'yellow': 1,
#  u'four': 4,
#  u'elvina': 2,
#  u'spiders': 1,
#  u"friend's": 1,
#  u'hanging': 2,
#  u'woody': 1,
#  u'looking': 28,
#  u'#buddha': 1,
#  u'kilda': 1,
#  u'otra': 1,
#  u'lord': 2,
#  u'#rawisbryan': 1,
#  u'hormone': 1,
#  u'gimmie': 1,
#  u'figs': 1,
#  u'grillteam': 1,
#  u'bringing': 2,
#  u'\udf6a': 2,
#  u'solid': 3,
#  u'#songsthatnevergetold': 1,
#  u'reliable': 1,
#  u'\ude14': 14,
#  u'\u2705': 3,
#  u'specially': 2,
#  u'tired': 3,
#  u'bacon': 7,
#  u'feasibility': 1,
#  u'second': 6,
#  u'#results': 1,
#  u'\udd29': 1,
#  u'fingers': 13,
#  u'increasing': 4,
#  u'succumb': 1,
#  u'hero': 1,
#  u'nawa': 1,
#  u'karibu': 1,
#  u'reported': 1,
#  u'china': 1,
#  u'wagyu': 2,
#  u'tamping': 1,
#  u'kids': 26,
#  u'k': 12,
#  u"i'd": 8,
#  u'karin': 1,
#  u"s'mores": 1,
#  u"i'm": 242,
#  u'rebel': 2,
#  u'golden': 3,
#  u'criticise': 1,
#  u'sweetest': 1,
#  u'explained': 1,
#  u'replace': 2,
#  u'brought': 1,
# ...

# %%
sorted(get_BOW(alltext).items(), lambda x, y: cmp(x[1], y[1]), reverse=True)
# Out:
# [(u'fat', 2276),
#  (u'\ud83d', 734),
#  (u'\u2026', 332),
#  (u"i'm", 242),
#  (u'\ude02', 239),
#  (u'obesity', 207),
#  (u'\ud83c', 197),
#  (u'like', 173),
#  (u'amp', 164),
#  (u'big', 163),
#  (u'get', 137),
#  (u'drinking', 121),
#  (u'\u2014', 119),
#  (u"it's", 117),
#  (u'one', 100),
#  (u'yak', 98),
#  (u"don't", 95),
#  (u'obese', 94),
#  (u'good', 89),
#  (u'overweight', 86),
#  (u'people', 79),
#  (u'time', 79),
#  (u'got', 78),
#  (u'\u201d', 72),
#  (u'2', 71),
#  (u'duck', 71),
#  (u'new', 67),
#  (u'u', 67),
#  (u"you're", 67),
#  (u'getting', 67),
#  (u'\u201c', 66),
#  (u'lol', 66),
#  (u'look', 65),
#  (u'food', 63),
#  (u'love', 62),
#  (u'day', 60),
#  (u'ass', 56),
#  (u'man', 56),
#  (u'back', 55),
#  (u'year', 54),
#  (u'eat', 54),
#  (u'\ufe0f', 53),
#  (u'need', 53),
#  (u'know', 52),
#  (u'loss', 51),
#  (u'fuck', 50),
#  (u'body', 49),
#  (u'today', 49),
#  (u'want', 48),
#  (u'#photo', 48),
#  (u'go', 46),
#  (u'think', 46),
#  (u'centre', 46),
# ...

# %%
sorted(get_BOW(bigramtext).items(), lambda x, y: cmp(x[1], y[1]), reverse=True)
# Out:
# [((u'\ud83d', u'\ude02'), 239),
#  ((u'\ude02', u'\ud83d'), 139),
#  ((u'big', u'fat'), 135),
#  ((u'drinking', u'fat'), 114),
#  ((u'fat', u'yak'), 98),
#  ((u"i'm", u'fat'), 71),
#  ((u'fat', u'loss'), 45),
#  ((u'get', u'fat'), 42),
#  ((u'getting', u'fat'), 39),
#  ((u'fat', u'ass'), 38),
#  ((u'fat', u'\ud83d'), 38),
#  ((u'obesity', u'diabetes'), 37),
#  ((u'like', u'fat'), 37),
#  ((u'\u2014', u'#photo'), 37),
#  ((u'cardiovascular', u'disease'), 36),
#  ((u'diabetes', u'cardiovascular'), 36),
#  ((u'fat', u'duck'), 35),
#  ((u'centre', u'obesity'), 34),
#  ((u'fat', u'man'), 30),
#  ((u'cp', u'centre'), 29),
#  ((u'hei', u'fat'), 28),
#  ((u'\u3000', u'\u3000'), 28),
#  ((u'duck', u'fat'), 27),
#  ((u'\ud83d', u'\ude0d'), 26),
#  ((u'body', u'fat'), 26),
#  ((u'\ud83d', u'\ude2d'), 24),
#  ((u'low', u'fat'), 24),
#  ((u'fat', u'cunt'), 23),
#  ((u"you're", u'fat'), 23),
#  ((u'fat', u'choi'), 22),
#  ((u'fat', u'cat'), 22),
#  ((u'kung', u'hei'), 21),
# ...

# %%
# coding:utf-8  
__author__ = "liuxuejiang"  

import os  
import sys  
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer  
  
if __name__ == "__main__":  
    corpus=alltext
    vectorizer=CountVectorizer()#该类会将文本中的词语转换为词频矩阵，矩阵元素a[i][j] 表示j词在i类文本下的词频  
    transformer=TfidfTransformer()#该类会统计每个词语的tf-idf权值  
    tfidf=transformer.fit_transform(vectorizer.fit_transform(corpus))#第一个fit_transform是计算tf-idf，第二个fit_transform是将文本转为词频矩阵  
    word=vectorizer.get_feature_names()#获取词袋模型中的所有词语  
    weight=tfidf.toarray()#将tf-idf矩阵抽取出来，元素a[i][j]表示j词在i类文本中的tf-idf权重  
    for i in range(len(weight)):#打印每类文本的tf-idf词语权重，第一个for遍历所有文本，第二个for便利某一类文本下的词语权重  
        print u"-------这里输出第",i,u"类文本的词语tf-idf权重------"  
        for j in range(len(word)): 
            if weight[i][j] != 0.0:
                print word[j],weight[i][j]
# Out:
# -------这里输出第 0 类文本的词语tf-idf权重------
# mum 1.0
# -------这里输出第 1 类文本的词语tf-idf权重------
# want 1.0
# -------这里输出第 2 类文本的词语tf-idf权重------
# breakfast 1.0
# -------这里输出第 3 类文本的词语tf-idf权重------
# want 1.0
# -------这里输出第 4 类文本的词语tf-idf权重------
# bacon 1.0
# -------这里输出第 5 类文本的词语tf-idf权重------
# eggs 1.0
# -------这里输出第 6 类文本的词语tf-idf权重------
# mum 1.0
# -------这里输出第 7 类文本的词语tf-idf权重------
# fucking 1.0
# -------这里输出第 8 类文本的词语tf-idf权重------
# mcdonald 1.0
# -------这里输出第 9 类文本的词语tf-idf权重------
# -------这里输出第 10 类文本的词语tf-idf权重------
# -------这里输出第 11 类文本的词语tf-idf权重------
# -------这里输出第 12 类文本的词语tf-idf权重------
# -------这里输出第 13 类文本的词语tf-idf权重------
# -------这里输出第 14 类文本的词语tf-idf权重------
# -------这里输出第 15 类文本的词语tf-idf权重------
# -------这里输出第 16 类文本的词语tf-idf权重------
# -------这里输出第 17 类文本的词语tf-idf权重------
# -------这里输出第 18 类文本的词语tf-idf权重------
# -------这里输出第 19 类文本的词语tf-idf权重------
# omg 1.0
# -------这里输出第 20 类文本的词语tf-idf权重------
# mum 1.0
# -------这里输出第 21 类文本的词语tf-idf权重------
# ...
